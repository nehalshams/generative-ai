# %%
html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8" />
    <meta name="viewport" content="width=device-width, initial-scale=1.0" />
    <title>Speech on Cricket</title>
</head>
<body>

    <h1>Speech on Cricket</h1>

    <p>
        Good morning everyone,
    </p>

    <p>
        Today, I am here to speak about cricket, one of the most loved sports in the world.
    </p>

    <p>
        Cricket is not just a game; for millions of people, it is an emotion. 
        It is played between two teams of eleven players each and requires skill, teamwork, 
        patience, and strategy. The game is played in different formats such as 
        Test matches, One Day Internationals, and T20 matches, each bringing its own 
        excitement and challenges.
    </p>

    <p>
        Cricket teaches us many valuable life lessons. It teaches discipline, because 
        success comes only through practice and dedication. It teaches teamwork, as 
        players must trust and support each other to win. It also teaches patience and 
        determination, because sometimes victory comes after struggle and hard work.
    </p>

    <p>
        Many legendary players have inspired generations with their performances, hard work, 
        and sportsmanship. Cricket has united people from different backgrounds, languages, 
        and cultures. During important matches, families and friends gather together to cheer 
        for their favorite teams, creating unforgettable memories.
    </p>

    <p>
        Apart from entertainment, cricket also promotes fitness, concentration, and leadership 
        skills. Young players learn how to handle pressure, respect opponents, and accept both 
        victory and defeat gracefully.
    </p>

    <p>
        In conclusion, cricket is more than a sport—it is a symbol of passion, unity, and 
        determination. It inspires people to dream big, work hard, and never give up.
    </p>

    <p>
        <strong>Thank you.</strong>
    </p>

</body>
</html>
"""

# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

headers_to_split = [
    ("h1", "heading 1"),
    ("h2", "Introduction"),
    ("h2", "The Game of Cricket"),
    ("h2", "Life Lessons from Cricket"),
    ("h2", "Inspiration and Unity"),
    ("h2", "Conclusion")
]

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split, )
html_chunks = html_splitter.split_text(html_content)

html_chunks
# Out:
# [Document(metadata={'heading 1': 'Speech on Cricket'}, page_content='Speech on Cricket'),
# ...
